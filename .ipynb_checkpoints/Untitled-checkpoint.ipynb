# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import GridSearchCV
from sklearn.decomposition import LatentDirichletAllocation
from sklearn.manifold import TSNE

from nltk.stem.porter import *
from nltk.stem import WordNetLemmatizer
import nltk
nltk.download('wordnet')
nltk.download('omw-1.4')
from nltk.corpus import wordnet 

import pyLDAvis
import pyLDAvis.sklearn
pyLDAvis.enable_notebook()
from sklearn.datasets import fetch_20newsgroups
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.decomposition import LatentDirichletAllocation

import gensim
# Out:
# [nltk_data] Downloading package wordnet to /home/traffic/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /home/traffic/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# /usr/lib/python3/dist-packages/requests/__init__.py:89: RequestsDependencyWarning: urllib3 (1.26.8) or chardet (3.0.4) doesn't match a supported version!
#   warnings.warn("urllib3 ({}) or chardet ({}) doesn't match a supported "
# /home/traffic/.local/lib/python3.8/site-packages/gensim/matutils.py:22: DeprecationWarning: Please use `triu` from the `scipy.linalg` namespace, the `scipy.linalg.special_matrices` namespace is deprecated.
#   from scipy.linalg.special_matrices import triu

# %% [markdown]
# # Bag Of Words

# %% [markdown]
# ### Preprocessing

# %%
df = pd.read_csv('analisis_comments_tiktok.csv')# Parameters tuning using Grid Search

def lemmatize_stemming(text):
    stemmer = PorterStemmer()
    lemmatizer = WordNetLemmatizer()
    return stemmer.stem(WordNetLemmatizer().lemmatize(text, pos='v'))
# Tokenize and lemmatize
def preprocess(text):
    result=[]
    for token in gensim.utils.simple_preprocess(text) :
        if token not in gensim.parsing.preprocessing.STOPWORDS and len(token) > 3:
            result.append(lemmatize_stemming(token))
            
    return result

comments = df.comment.tolist()
comments_prep = [preprocess(str(comment)) for comment in comments]
comments_dict = gensim.corpora.Dictionary(comments_prep)
bow_corpus = [comments_dict.doc2bow(doc) for doc in comments_prep]

# %%
comments
# Out:
# [nan,
#  'it’s not good chegg apparently rats out on students',
#  nan,
#  'I hope Audri looks different at that age',
#  'I absolutely love it!',
#  'so this is what Audri will look like as a Freshman in College? 🤣🤣🤣🤣🤣',
#  'Oh my I hope not 😂',
#  'Math is hard 😳😳😳',
#  'This was me. I cannot MATH',
#  'I can history all day long but I cannot math or science… and sometimes I can’t English 😂 what about you?!?',
#  'This is so neat! @Chegg for the win!',
#  "That is a 7th grade problem😑 Won't work on my maths.",
#  'Why you holding a charger up to your mouth',
#  'I thought you were a nun',
#  'same oh my gosh is this an actual sponsor thing or a joke',
#  'wait how am i so early',
#  'GET 5 DOLLARS OFF your first month of Chegg Study Pack using the L1NK IN MY B1O!!!!📚🌙✨',
#  'Early',
#  'I thought this was a fake add-',
#  'I can never tell if your joking or not HELP-',
#  nan,
#  '🥰💝🇺🇸 no 🇺🇸🇬🇧🇨🇦😄😱🥰',
#  'YI殺Where are you guys❤️',
#  'chegg is terrible. they log your ip and send it to schools. so many kids have been honor coded cuz of chegg',
#  nan,
#  nan,
#  'MANS😍 STARE AT MI ACCOUNT 😳🙈🙈',
#  'earlyyyyy',
#  'Ayyyy legend',
#  'Are you serious',
#  "Yes it's college but it's called university",
#  'Your such an amazing person 😁',
#  'Cappp it to get 2 days for a freaking reply',
#  'soooo how much bread did you get with this collab',
#  '4 people can’t be first for god sake',
#  'So I’m the only one that cries on the first day of class Bc stress? Ok \U0001f972',
#  nan,
#  'Important topic',
#  'Have had this for four months I am hoping by month 5 or 6 it will be completely gone I have improved  a little. 21 year old male',
#  '@La Gatita Yes',
#  '@La Gatita in my experience',
#  'I&#39;ve heard this often goes with anciety/ depression. I&#39;ve had that and I think having mono made them all worse.',
#  'Thanks<br>Very informative 👍',
#  '@Tom Saywer I can be gone for months and then yo into full panic mode.',
#  'Not me self diagnosing.. 😬',
#  'I didn&#39;t even know this existed.<br>Thank you.',
#  'Bakeing soda and water with Lemons along with your minerals and vitamins and don’t listen to this net wet because he sure does have all the symptoms down to a T but he has no idea how to heal the body this is not healthcare this is ignorant death care',
#  nan,
#  'Goo😀ood',
#  'I had mono. Cleared now I have high EBV loads that have caused chronic fatigue for years. My daughter is doing this too. I got mono caring for her when she had mono. I got it as an 40 ye old....she was 10.',
#  'lyme disease maybe...',
#  'Falling asleep whilst watching this....zzzzzzzzx',
#  nan,
#  nan,
#  'Excellent as always',
#  'For somebody who is so educated is so ignorant because it can be cured with minerals and vitamins vitamin D three magnesium magnesium mulch chronic fatigue is more likely link to anemia. This is a case of Somebody who went to school and got the books and read them and tested on them but has absolutely no knowledge on the matter of the issue on hand and has no idea how to heal the body this is a prescription writer this is that care not healthcare',
#  'Falling asleep whilst watching this....zzzzzzzzx',
#  'Please molecular bio b krwa do 🙏🏻',
#  'Epstein bar causing my CFS. It&#39;s a monster. Wishing all who see this healing. Happy Holidays.',
#  'I&#39";ve never had any trauma and not much stress what I would class as normal level with school exams etc and I have ME there&#39;s other reasons not just trauma 🤷🏻\u200d♀️',
#  nan,
#  'Thank you as always. You are the most helpful',
#  'Dr Ogbomon on YouTube has finally cure me from Herpes virus permanently with his herbal medications',
#  'Hey great information',
#  'ENABLE SUBTITLES PLEASEEEEEEEEEEEEEEEEEEEEEE...........',
#  'Thanks',
#  '👍',
#  nan,
#  'I hit the like before watching the video 😂',
#  'The Greatest',
#  'Perfect perfect perfect perfect perfect',
#  nan,
#  'I appreciate my lovely husband for directing me to this holistic herbalist called Dr alaho olu i met on YouTube. He cured my herpes simplex virus…',
#  'Hi Sir. Your videos are amazing. I really appreciate the efforts you put in to make such great vidoes. Your videos really helped me during my entrance preparation for post-graduation. Thank you very much. I am planning to take Dermatology sir. I need your guidance. Is there any way I can contact you?',
#  'Great',
#  'A Medical student AND a Crohn’s patient here... thank you from both perspectives :)<br>Didn’t watch yet but I’m sure it’ll be as amazing as always !',
#  'Upload lectures on HIV and AIDS',
#  'Please I need meiosis!!!',
#  nan,
#  'Great video as always guys ❤️',
#  'I love you',
#  nan,
#  'The heavy or frequent use of antibiotics could be a part of the problem.',
#  nan,
#  'I like your cool videos',
#  'pls explain ulcerative colitis also',
#  'Getting rid of herpes virus was hard for me I had HSV for years and then I came across  Dr Idakwo on YouTube who used his herbs to cure me and now I’m cured',
#  'You are amazing man',
#  'lets go brother ! youre perfect ! plz give more free videos !',
#  'Ninja nerd I&#39;m so happy that you choose that subject today. First comment!!! For the first time. LoL. Please next talk about ulcerative colitis',
#  nan,
#  nan,
#  'You are amazing man. Thanks for this topic..<br>We need Ulcerative colitis also....',
#  nan,
#  nan,
#  nan,
#  'That’s interesting. I’m a nurse on a GI ward and I’ve been noticing a bit of an upswing in numbers of young people with new or flares of Crohns. It may be co-relation',
#  'Everywhere is a trace of immune system 😂😂😂.You are emazing zack👌👌👌',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'I want to recommend you all to Dr osaba on YouTube who cured my herpes virus within 14days after using is medicine God bless you  sir .',
#  nan,
#  'Thank you 💖!<br>Zach &amp; his team',
#  'Thank you so much .... If you all can make video on short cases examnations that we might get in final mbbs❤️❤️',
#  nan,
#  'Ninja nerd I&#39;m so happy that you choose that subject today. First comment!!! For the first time. LoL. Please next talk about ulcerative colitis',
#  'Tq',
#  'Thanks Zach 👍👍',
#  'CS";;;;;;',
#  nan,
#  nan,
#  nan,
#  'Pleural effusion please 🙏',
#  nan,
#  'CS"',
#  'Zach must be psychic or something cuz my upcoming exams are about nephrology and gastroenterology',
#  'For the information I am greatful.Thanks!',
#  'Could you please make a video explaining horner syndrome in it? <br>Thanks in advance',
#  nan,
#  'love the storytelling style!',
#  'Such a nice teachings ... Thank you so much',
#  'God bless you and team',
#  'this guy is amazing I could watch this for hours without losing interest',
#  'You are a big library man. Thanks a lot and keep doing.......',
#  'Thanks',
#  'Well explained👍... Thank you',
#  'This is awesome! I have Crohn’s and I will be showing my gi doc! Amazing work 🤩',
#  'you are god my friend',
#  'Okay but I love how realistic this is because it is really hard to plan meals and everything while you are in college ( lol I love the fact that I&#39;m talking like I&#39;"m a college student) 😂😂',
#  'sydney are you proud that i got christmas socks today',
#  'Firsttttt',
#  'Pretty girl',
#  nan,
#  'I love you girl 💟💟💟💟💟💟💟💟😘😘😘😘😘',
#  nan,
#  'I kind of love how being healthy and happy is trendy',
#  'No hate to syd at all I literally adore her with all my heart but it&#39;s crazy how much microwavable meals and processed food Americans have..I&#39;m from india here it&#39;s all about home-cooked meals!!',
#  'Why have everyone forgot about her already',
#  'I’m British and yes the weather really gets to me unfortunately. Walking to college in complete darkness in the winter isn’t great but I get by :)',
#  'Nice ❤️',
#  'pov: you have been in the same parking lot as sydney serena. i used to live in orange county by the orange circle but then i moved to a diff state',
#  'Can we talk now yes or no',
#  nan,
#  'Did you know all college systems including CUNY are strict?',
#  'Yes Sydney the weather does effect my mood',
#  'Sydney pin if you love your fans ❤️❤️💗',
#  'She has peanut butter for literally every thing',
#  'HII',
#  'Tienes que mejorar tus platios. Mi mama te gana en la cocina facilito.',
#  'Does anyone else also not have time do eat while in college ? 😭😭',
#  'Try arabian food',
#  'SYDNEY MY LOVE !! You look so happy',
#  'comfort ytber',
#  'Isn’t Trader Joe’s expensive? How are food supples in Orange County?',
#  'I love you so much....Following these videos from Iraq and also I hope that Iraq will become like your country 😘',
#  'First 9 seconds',
#  'Friends with me yes or no',
#  'Hi',
#  nan,
#  nan,
#  'I&#39;m from India and jst loveee ur vids... it feels like if ever I get to meet u in real life I would have been able to talk and enjoy with u the whole day without any hesitation... u feel sooo homely and friendly.. loads of love and bestest wishes for u.. keep glowing and growing...',
#  'Enjoy your meal! YYYyyyyeeeaahhh!👅😀Blue thumb for your video!',
#  'hi syd its 4am now idk what I&#39;m doing i need help but I love u and ur videos okay bye',
#  'Love you syd!!',
#  'ILY UR VIDS ARE SO FUN',
#  nan,
#  'You look beautiful🤩',
#  nan,
#  'Love the vid syd',
#  'I&#39;m the only one who stressed about people cutting so much part of strawberry! 😫😃',
#  'I used to love your videos where you attempt to bake so I’d love to see you make Xmas cookies or cakes🤍',
#  nan,
#  nan,
#  'Omg I love whenever you post!!',
#  'And all the food look so good!!',
#  'THIS IS NOT ENOUGH FOOD !!!!!<br>EAT MORE!!!!!',
#  'Hello there',
#  'this is making want to be healthy instead of the usual which is like 90% high fructose corn syrup lol',
#  nan,
#  'Sydney! I would love to see a nail inspo board on your pinterest!😚💅🏻',
#  'syd&#39;s vlog is all that we need😌❤',
#  'Turkish subtitle please we love you',
#  'Your videos are so inspiring. You eat so healthy.',
#  'So cool i love it 🤩😍',
#  'EARLY',
#  'Your videos always make my day &lt;3',
#  'Hiii . So much love for you Sydney 💗😘💗💗💗',
#  'What about sausage?',
#  'Lllp lo',
#  nan,
#  'You’re so healthy!',
#  'يمه منذ دقيقه👀👀',
#  'guys syd’s eating healthy?!?!?',
#  'idk why but i find syd&#39;s videos are super chill and relaxing to watch<br>also not me thinking chegg was a person-',
#  '❤️❤️',
#  ':)',
#  nan,
#  'Eat in a week IN college',
#  'it is typicial for americans to et worried aout weather because americans are norweigian.',
#  nan,
#  'Ur so gorgeous Sydney',
#  'Omg syd is so grown up now ahe kinda looks different',
#  'WAIT! Syd likes coffee now!!!',
#  nan,
#  'can we talk abt how syd completely clickbaited with that thumbnail LOL  <br><br><br>(y’all this is a joke btw no hate i just think it’s funny)',
#  'Hey queen 👑',
#  nan,
#  'I am playing the video but it says &#39;this video is unavailable on this device&#39;....',
#  'Chocolate raspberries',
#  'Garlic is very healthy',
#  'Yes unfortunately the weather can affect my mood',
#  'Pin this for absolutely no reason at all',
#  'You have trouble with chemistry ⚗. For me it was potions 😂. But my spells were 👌. Love the intellectual but cute look with the glasses 👓. They suit you 😘 🌹',
#  'IVE BEEN A FAN FOR OBER 4 YEARS',
#  'Nice 🧬’s',
#  'watching u from france!!! ilysm &lt;3',
#  'IM SO EARLY OMH',
#  '&quot;Aten&quot;?!',
#  nan,
#  'her intros are so aesthetically pleasing',
#  'What the actual heck was the blur in the beginning',
#  'Damn im early today love you sid kisses from belgium xx💋',
#  'AMAZING GIRL',
#  'CAN I GET A HEY ??',
#  'hey i love you:)',
#  'I kind of love how being healthy and happy is trendy',
#  'Trader Joe’s 4 life lol',
#  nan,
#  'This was so fun. U honestly eat so balanced and healthy',
#  'this literally made me wanna eat',
#  'I love your video!! I study English by using your video!!',
#  'sydney where’s is the mirror in your room from? it’s so pretty 💘',
#  'Ho! My god please be carefull with the knife',
#  'Loved this video Syddd ❤❤ Reminded me of the good old days and your past videos :) so chill and spontaneous',
#  nan,
#  'AYYYYY',
#  'I&#39;m the least healthy person all I crave all day is sugar and it&#39;s a problem.',
#  'How has your day been?',
#  nan,
#  'I love Sydney’s videos so much and I never miss a single one<br>I’ve been watching her for three years now &lt;3',
#  'Nice to see your video syd',
#  'Love your outfit and your plans.  Thanks for sharing this sweetie.',
#  'Hi!',
#  'I&#39;m looking at it from Japan( ¨̮ )!!',
#  'I kind of love how being healthy and happy is trendy',
#  nan,
#  'You are look like Duygu Özaslan',
#  'Friends with me yes or no',
#  'the thumbnail✨',
#  'Your video gives such an aesthetic vibe 💗😩',
#  'Your vids are my favorite!! Also love your editing 😊',
#  '😍😍😍',
#  nan,
#  'How can you eat that small... Is this really how much some people eat in a day? No hate just surprised',
#  'Love you syd☹️💗',
#  'Okay but I love how realistic this is because it is really hard to plan meals and everything while you are in college ( lol I love the fact that I&#39;m talking like I&#39;m a college student) 😂😂',
#  'CS";;;;;',
#  'Your so pretty omg',
#  'I watch your videos all the time and they&#39;re so funny',
#  nan,
#  'First love your vids hope your college is easy for u',
#  'Best channel I&#39;ve seen keep it up🤍🇸🇦',
#  nan,
#  'Veryyyy good sedney❤️',
#  'i just woke up to a new video and i couldn&#39;t be happier! love your videos!!✨💕',
#  'FIRST',
#  'Yess this is a thing I&#39;ve been saying for years. Weather really affect our mood. Sunny weather always make me soo energetic while cloudy days make me lazy 😌',
#  'Love you so much but when you said “bon appetit” I thought you said “bueno petit” and I was really confused 😅',
#  'You need to put some salsa on that wrap',
#  'If it’s vegan it’s vegetarian',
#  'syd you’re gorgeous!!',
#  nan,
#  'Love youuuuuuu pretty 🥰❤️❤️❤️',
#  'Omg I love you so much',
#  'you lowkey look like angelina jolie',
#  'Good Vlog Video as always <br>😻Lovely thumbnail tho😻<br>Your Pretty Self <br>Keep Them Coming <br>Happy Fabulous Weekend Too <br>😇Stay Bless n Be safe always😇',
#  'Omg yes I’ve been missing your videos!!',
#  'Hello 🌸',
#  'I had a bad week and wanted Syd to upload and she did yay!!! I am in my 30s and live alone….I cooked more 4 times a week when I first moved out in my 20s. Now I just cook twice a week and eat out or go to my parents for dinner. <br><br>Cooking for one person is hard so I either just buy food or food that I can warm up……easier for me.',
#  'Love you 🤍🤍🤍🤍',
#  'OMG HI',
#  'Do yall remember when Sydney didn&#39;t like caffee. 😆 those were the times',
#  'This sucks I can&#39;t seem to watch your vlog it says it&#39;s unavailable',
#  'remember when Sydney was a vegan',
#  'this video should be sponsored by trader joes LOL',
#  'First',
#  'Hi',
#  'YOU NEED TO EAT WAYYY MORE FOOD !!!!!',
#  nan,
#  'I loved you more u are my fv youtuber 💗😁',
#  nan,
#  'Awww🤤💞',
#  'Syd I dare you to pin this!',
#  'Hryyyyy',
#  'she literally owns my heart &lt;3',
#  'your life is so aesthetic 💕💕',
#  'Love you babe!',
#  'We get you Syd college life can get to you sometimes lol but everything did look yummy 😋 Love you xoxo 🤍🤍🤍',
#  '🤍🤍🤍',
#  'Great video! ❤️',
#  'can u do a day in ur life video?<br>ps: i love u',
#  nan,
#  'You look gorgeous without makeup 💙💙',
#  'Her vlog is very comforting! Please keep on doing goodwork syd we love you',
#  'Missed u',
#  'Pin this cause why not',
#  'My finals are just two days far🧘🏻\u200d♀️😭😭😭',
#  'Syd ur life is such a vibe I love it!',
#  'Be careful guys! Some universities see Chegg as academic dishonesty and you can get in a lot of trouble.',
#  'you came early and you don&#39;t know what to write😂😂😂<br>Hi from Azerbaijan 🇦🇿💜',
#  'I love your videos so much Sydney',
#  'The thumbnail looks so aesthetic!!',
#  nan,
#  '4th ahh ily Sydney',
#  'Yay first x',
#  'I love your dimples sm 💜',
#  'Love from India ❤❤❤',
#  nan,
#  'did u get sponsidered by trader joes',
#  nan,
#  'Hi',
#  'Eu adoro seus vídeos ❤️',
#  'SYD I KNOW YOUVE DEFINITELY SEEN THOSE REINDEER CAKE POPS AT STARBUCKS. IF YOU HAVENT SEEN THEM YET IM PRETTY SURPRISED',
#  nan,
#  'Early af',
#  'What happened at first 😭?',
#  'حضكم عندكم الصبح',
#  'Sydney: &quot;what i eat in a week at college.&quot;',
#  'Hey Syd! this is Kloud from Kesem! thanks so much for the little gift😉',
#  'Yess the weather has my mood everywhere!! It&#39;s honestly very weird 😅',
#  'I can’t watch it😭 just kidding now I can!',
#  'Friends with me yes or no',
#  nan,
#  '~~~★',
#  'i love watching these videos!!',
#  'I don’t think your fridge likes you 😂',
#  'Syd are you vegetarian?',
#  'syd is so cool and comforting. Wow.',
#  nan,
#  nan,
#  'i think syd really likes trader joe’s',
#  nan,
#  nan,
#  'did she skipped thursday',
#  'Hy I&#39;m from fiji',
#  'hi sydney where did u bought ur slippers?',
#  'HI',
#  'YESSSS',
#  'the fridge hahahahha',
#  'i litteraly love ur videos smm',
#  'Yes the weather is a thing syd it also get me I feel kind of unproductive and sad when it&#39;s cloudy',
#  nan,
#  'I missed you syddy 🥺 You&#39;re so pretty Lysm ❤️',
#  'EARLY',
#  'is this university of washington?',
#  'Use course hero instead',
#  'hiii";;;;;;',
#  nan,
#  'I live in ethiopia big fan by the way...my school grades are between good and average can I get a scholarship?',
#  'Yep lmao',
#  'i mean i’d assume so',
#  'Worth every penny!!!!',
#  nan,
#  'It got answers ?',
#  'We’re not allowed to use this at my university 🙃',
#  'Congratulations',
#  'Chegg is not that good and you have to pay for it',
#  'Excellent resource! Bravo for posting! HS college counselor here....you do great vids',
#  "is it possible for kids like me to win scholarships if we're homeschooled through highschool",
#  'Yup',
#  'First',
#  '5 mins',
#  'hi',
#  'In first for a first 😳',
#  "I'm**",
#  'hi',
#  nan,
#  '21st. 😂😂',
#  'Oh come on now',
#  'yessir😂😂😂🥰🥰🥰',
#  '😳😂',
#  '😂😂😂 now I will check out Chegg',
#  'Chegg is the reason I will ruin lives as a doctor',
#  'Hey',
#  nan,
#  'haha',
#  'They grow up so fast',
#  'omg lol so this is what Audri will look like 😂🥰🥰',
#  nan,
#  'And then she woke up and remembered every single one of her other teachers assigned home work',
#  'I would hope so 😂',
#  '🥰',
#  'Any tips or website for writing a long paper? 😬',
#  'As far as Im aware they dont 🥺',
#  'How did you get through chem 😫',
#  'OMG ealryyyy can you say hi??',
#  'Same',
#  'I still don’t believe algebra is a needed skill for certain professions it is but my job I never deal with any thing more then affliction and sub',
#  'Stuff',
#  'for your story times how do I send you my story',
#  'This helps',
#  'Conner: 👁👄👁',
#  'My student loan gives me chegg for free for 6 months',
#  'Khan academy',
#  'i am the exact opposite of you',
#  'chegg is great but you can also use symbolab and khan academy :) coming from a math student and khan is free',
#  'Going to a different math teacher once helped me with a math problem because I definitely needed my problem explained in a different way ☺️☺️',
#  'As a',
#  'I actually use chegg for my college classes aha. Online bachelors degree for game design at full sail university chegg really does help',
#  'English was the hardest for me math and history was my best subjects',
#  'Posted seven minutes ago',
#  'I love your marvel posters!',
#  'Downloaded as soon you said has all other stuuf',
#  'early',
#  'Math is from the devil.',
#  'I’m an English teacher and sometimes I can’t English too. 😅',
#  nan,
#  'Khan academy',
#  "Dang it I'm late",
#  '😂 Conner is such a classic character!',
#  'Kahn academy is the MVP for explaining math tbh... and its free 😏',
#  '2nd',
#  nan,
#  'I finally found you I always see u I. YouTube',
#  'Miss Rogers was mr. Rogers a father😂😂😂😂😂😂😂😂😂😅😅😅😅😅😅',
#  'You are such an amazing teacher!',
#  'I can’t math either',
#  'and more you just said that is has text book',
#  'technically math is a language',
#  'Omw to get my grades up 😭🤚',
#  'My class ends next week this would’ve helped me sm 😭',
#  'Brutal',
#  'This Cheggs out 😎',
#  "I don't have to wait for my salary anymore and every of my dept has been paid...its all because @KARINA REEVES",
#  'That’s easy stuff',
#  '😀😀😀wow thx have a great day and have a wonderful day',
#  '55 mins ago',
#  'Nah i jus guess and keep it pushin',
#  'Early',
#  'I’m a cutie',
#  'grade 11 be like!!!UwU',
#  '@TOM you can also just scan it with Snapchat for the answer 😏',
#  'they have also the test',
#  'hi',
#  'I cant tell if this is cheating or not? 🤔',
#  'teacher will watch you video😂',
#  'or listen in class',
#  'It’s grade 10 lol',
#  'ahhh thanks a million ur a life saver😅',
#  'Omg thank nu so much',
#  'No its not 😳',
#  'Yayyyy',
#  'R u Slavic?',
#  '4xplus5y isn’t grade 10 it’s so easy',
#  'had us at the first part...',
#  'Just scan it on snap',
#  'Gauth math will help',
#  '@Tanz.szn 😂😂 we finally have something helpful for us in Maths',
#  "that's easy bro",
#  'Bro where u from?',
#  'Or just download mathsway take a pic of the answer or type it in and it shows u you don’t have to pay 😁',
#  'yes but doesnt work on other country math',
#  'Anybody else notice he’s speaking into the the part you plug into the phone?',
#  nan,
#  "just use gauthmath it's free and it does the same thing",
#  'This is what we learn in Romania in the 6th grade😏',
#  '😏',
#  'thanks',
#  'Thinks its a microphone 🤣🤣🤣',
#  '@emma.devl photomath ✨',
#  'hi',
#  'That sounds amazing',
#  'Nah F that chegg are snitches use Gauthmath that’s the one',
#  '👍',
#  'I always try to reply 🥰',
#  '👏🏽👏🏽👏🏽👏🏽🤗',
#  'Thank you for giving us citation advice. I am a student and need all the help I can get. 😬',
#  'I love you more!',
#  'Love it!! I’m in masters program for NP. Yes to you and all you do!',
#  'yayyy she really replied',
#  'I really appreciate that! I also appreciate you engaging wjhh TA my sponsored content. It really helps!',
#  'Beauty and brains yeah',
#  'Umm I like your vid🥰',
#  'i used chegg last year best ever',
#  '🥰🥰🥰',
#  "I'm getting Nia Long vibes whenever I see you. Both are beauties 😏",
#  'you are so beautiful',
#  nan,
#  'Yes 🙌🏾',
#  '👍👍👍',
#  'I Would love to be in one of your Classes ☺️🌹',
#  'interesting 🥰',
#  "🥰🥰🥰... You're marvelous 🥰",
#  nan,
#  'you have great content bmf?',
#  'Thank you!!',
#  '🥰🥰🥰🥰',
#  'woaw',
#  'early',
#  '💖 i am about to send this vid to all my friends',
#  'I knew you was giving teacher vibes 😅😅😅🥰🥰🥰',
#  'Is this a joke or not I’m so lost😳',
#  'I don’t know',
#  'you looked like a nun',
#  'okRRRR',
#  'And then you realize you’re stuck on question one and it’s due tomorrow 😭',
#  'no I stay up all night or until 5:00am',
#  'For me its the same except I had one night to do all the assignments from the year...pretty simaliar though',
#  "something that's free in a good idea just use the Google calculator",
#  'i can’t tell if this is real or not',
#  'U should be verified',
#  'GUYS STAY SAFE ON CHRISTMAS SANTA IS FARTING INSIDE EVERY PRESENT WHEN YOU OPEN IT IT WILL SMELL LIKE SH!T ⚠️STAY SAFE⚠️!',
#  'It’s an all guys school',
#  'No this be history',
#  'One class nahh it’s not one it’s all for me',
#  "chegg snitches on you !! don't use it 😉",
#  'No all boys school',
#  'How do you need help with photosynthesis we did that in frouth grade',
#  'No it doesn’t',
#  'AINT NO WAYYYY',
#  '😁',
#  'First of all I saw two kids they look the same exact look',
#  'BOWJACK?!',
#  'hi',
#  'This is 💯 accurate 😂😂😂😂',
#  'no',
#  'Yes...',
#  nan,
#  'Everyone I took it too is saying just about the same price cause apparently the piece is expensive',
#  'this is an add',
#  nan,
#  'Please help cause the class action was thrown out even tho the judge agreed',
#  'Not yet',
#  nan,
#  nan,
#  'Chegg literally had a class action lawsuit for a data breach not long ago. Ask me how I know 😏',
#  'recommend that call a CREDIBLE 3rd party repair business and tell them about your issue and they can probably sort it out for way cheaper than Apple',
#  'Fixed the issue w/ 2018. Never checked if 2017 had the same issue. Now they want me to pay 950 to fix something they diagnosed as the fan',
#  '🥰🥰🥰',
#  'sounds like something Apple would do',
#  'Did the second cereal lawsuit never pay out?',
#  'I have a 2017 model that I spent 4K on including AppleCare. Apple will only fix 2016 models for free said eff 2017 as a whole discontinued my modelz',
#  '❤️❤️❤️',
#  'what kind of business sense does this make for them!? I had not heard',
#  nan,
#  'Me too. Love the way you present EVERYTHING! And really really love your style too',
#  "and it's paying out several hundred per claim",
#  'Lol yt boy',
#  '@thund3r_ju4n',
#  '@photomath',
#  'Hii',
#  'So you chegging on chegg',
#  '@issabell13nolan',
#  '🥰🥰Ily',
#  'Go',
#  'Dead!!!😁',
#  'ayyyy you are THE BESTTT 💚 WHATS upppp???😏',
#  'congratulations on one million ✨💃',
#  '0ne day ago!',
#  'BRO U ARE TO FUNNY',
#  'It says I need a code for the promo',
#  'yes ryan get that promo',
#  'Dose this work for highschool?',
#  nan,
#  'early😳',
#  'Does the king respond 😏',
#  'Congrats on 1 million followers 🎉',
#  'Was that Harry Potter',
#  'Why does the caption move',
#  'LOL',
#  'I don’t stay up to study I just stay up',
#  'ayyyy',
#  'congrats',
#  'EARLY 😁 LOVE YOUR VIDS!!',
#  'Wear orange in your next video if you need help 🥰🥰🥰',
#  'Should’ve had Cegg',
#  'i heard money and gave up 👁👁',
#  'congratulations for the 1m subscribers😁😁',
#  '@twicycle bestie I think we need thus',
#  'Congrats on 1M!! I love you vids ❤️',
#  'Happy 1 mil',
#  'if i got chegg as a gift i would fucking die @Antedragz',
#  'That’s a different thing in my country tho',
#  '：Ce gars est une legende 👏',
#  'Omg your so nice',
#  'What a gift',
#  'HEAVEN NOW',
#  'I love your page @itssozer 🥰😁',
#  'Why would anyone ever hurt you? Your the nicest person I know🥰😁',
#  'hii I have CRPS a very rare disease and my mum dose not have enough money to pay for my medical bills',
#  'Yes it’s university',
#  'Why don’t you guys get some goods from the soulmia app🥰',
#  '@Antedragz',
#  'The best',
#  'is this sponsored? idk what gave it away😳',
#  nan,
#  nan,
#  nan,
#  nan,
#  'uni means university and usually a uni will have lots of colleges under it that have different fields and majors you can study',
#  nan,
#  'sorry to educate myself',
#  'You are awesome nice kind and it makes me and everyone happy',
#  'This guy literally always makes my day',
#  'He’s in Adelaide',
#  '@jenna.michellle RAWR',
#  '🙌❤️',
#  "Uni is so hard! so happy to see you're supporting some uni students",
#  'Hi',
#  "it's just to much effort and I hate school",
#  'I’ve been following for a year! I’m making you a go now!',
#  'Hi',
#  'Emily are you single?',
#  'Ty for replying 😊',
#  nan,
#  nan,
#  'How are y’all feeling this semester?',
#  'i follow',
#  'did just study you make me ashamed',
#  'Smh',
#  'i love when u do magic',
#  'ye',
#  'Who is early',
#  'thanks know i can do my homework😂',
#  '🧐😱',
#  'me',
#  'now*',
#  'Ur so prerttyyyy?',
#  '@Pacob U need',
#  'YouTube pose video',
#  'Hi',
#  'Thanks bestie',
#  'First-',
#  'u make me buy glasses😅',
#  'Hiii early',
#  '9th',
#  'hiii',
#  'Can you do the natural blush challenge? 😍',
#  'Ya haha',
#  'Hi',
#  'I’m had a bad reaction to blue light',
#  '🥰🥰🥰❤️❤️❤️',
#  '@Riley is this the place ur mom used to work for',
#  'congrats on the sponsorship !!!! ♡♡',
#  'I loved Chegg ebook rental in grad school!',
#  'I love your hair!',
#  '🥰🥰',
#  'There is always an assignment 🥰',
#  'Also khan academy',
#  'how can you get ahead in the holidays before starting biology 3/4',
#  '🥰🥰🥰',
#  'do you suggest atar notes?',
#  nan,
#  'This is dope!',
#  'Would you say studying the practice questions from your textbook be effective?',
#  'I would choose subject that I enjoy but if you want to take year 9 serious then pick subject that might help you when your older.',
#  nan,
#  "yh no we have to pay and I'm toooo broke",
#  '🙂',
#  'We will help!!',
#  nan,
#  'What can you choose from?',
#  'Hey what electives do you personally recommend for yr9',
#  nan,
#  'We will answer all of your maths questions for free !!',
#  '🥰🥰🥰',
#  'Happy mood activated not for the first time but for the 3rd time still getting paid all thanks to a wonderful account manager @official.annaclaudia',
#  'We can help with maths! For free',
#  'Use a grid of the region and select evenly distributed controllable areas and carry out a transect in each',
#  'We will answer your maths questions for free !!',
#  'Of course!',
#  nan,
#  'What I would like to know is how do you read and grade all those papers ?😅',
#  'Wow! College instructor?? Can I pic your brain?',
#  'LINDA🥰🥰',
#  nan,
#  'It’s literally why I haven’t been active on Instagram. I’m stressed 😫',
#  'LOVE YOU',
#  'Of course!! 🥰🥰',
#  'BEAUTIFUL',
#  'I LOVE YOU',
#  "Guurl you're so beautiful 😍....can you show your nails too",
#  'Love you more!!!🥰🥰🥰',
#  'wanna know how you did to you scaf.',
#  "I'm your fan",
#  'BRASIL 🇧🇷',
#  'Thank you!!🥰🥰🥰',
#  'thank you for doing it wz passion',
#  'Do they help with accounting',
#  'would’ve been life saving',
#  '😳',
#  'YAY I LOVED THOSE',
#  'LITERALLY',
#  'hello',
#  'YESSS NEED THIS THANKYOU CLOUTOM🙏🙏😊',
#  'Does the king reply',
#  'Yep 😂',
#  '20th❤️',
#  'Guathmath',
#  'how do you do your hair pls Tel meee',
#  'Hiii',
#  'Going to get an A😳',
#  'Google :)',
#  'What are you studying??',
#  'But is it free',
#  'Love the hoodiee',
#  'Does it wirk with french biology questions??',
#  'Earlyyy',
#  'i allways using brainly😅😅',
#  nan,
#  'most problems are in there tho',
#  '*lernt',
#  'so it took you almost 4 hours for 1 question.........',
#  'Where the link?',
#  'mathway and askrose.org',
#  '@gursimrann29',
#  'Guess',
#  'Nope… I’ve been waiting for 10+ hours so no thank you I’d rather do it myself and google it or sum',
#  nan,
#  'ouais',
#  'Is this free',
#  '3 hours for one prob 😳 before U thought of chegg 😳 or just moved on 😳',
#  'early',
#  'Hiii',
#  'Early',
#  'Early queen 🥰',
#  'Same',
#  'First',
#  'Oh wait nvm I thought that was just the video nvm it’s an add',
#  'u started studying with chegg 😁',
#  "I didn't even know this was a ad",
#  'omg you replied :)',
#  'Heyy queen love you babe',
#  'I am in middle school and I’m already at that point last week and I’ve been in school for seven weeks',
#  '@mayy_karim__1 brevet',
#  nan,
#  'First',
#  'God bless Jesus saves!',
#  'hi',
#  '🥰',
#  'Wait so this app is basically a virtual tutor?',
#  'Oh girl I already got to that point when we had homework in the summer 🥺😂',
#  'this is every point in my semester.',
#  'First!!',
#  'hello gday super get account.',
#  'This is literally me every time I get hw',
#  'early',
#  'LOL',
#  'First',
#  'early 3 minss',
#  '3min ago',
#  'First',
#  '@_regan_ @sachi.forbs me',
#  'Uhhh if I use chegg my uni literally expels me',
#  'most of it isnt very helpful for those outside the USA',
#  nan,
#  'This hairstyle needs a tutorial 😩. You should see how my hair looks right now after attempting 4 times.',
#  '☺️',
#  'starting college in the spring definitely going to use this',
#  "I'm not in school but I could use this in my life..... I think 🤔",
#  'my daughter ❤ is in 9th grade I got her to an AAplus student I send this video to her....Thanks👍👍👍👍👍',
#  'You look like my family member shakes',
#  nan,
#  nan,
#  'No',
#  'you have to daughters',
#  '😂😂',
#  'Hey',
#  '😂 So so true 😂',
#  "wow Audri grew up fast. It's like only yesterday she was in elementary",
#  'Cliffs Notes 😂😂😂',
#  'Good question',
#  '🥰🥰😂',
#  'Hiiiiiii',
#  nan,
#  "😂😂😂😂would have been nice to have this in school huh? we didn't even have the internet yet😳😳😳",
#  '😁',
#  'the dressz😂😂',
#  '😳',
#  'Audrey must be at a friends house.. HAHAH',
#  "do they offer scholarships because it won't let me take to the scholarship",
#  '🥰@',
#  'Chem was rough! I used @Chegg !!',
#  'hi',
#  'Will Chegg help me study for my pilots license? 😂',
#  'dam 🥺',
#  "Gothmarh is better than Chang it let's you take a pic of the homework and gives you the steps if you still don't understand they have tutors to help",
#  'Lol who knows',
#  'Frist lol',
#  '🥰🥰🥰🥰',
#  'firstt',
#  'And she sticks the landing 👏',
#  'Jeez 10? Never bro that’s 7th',
#  'Bro I’m broke can’t even afford 5 dollars😂😂',
#  '@Hashii dùng cách này không sợ toán nữa rồi 💃',
#  '@Loic.U jaaaaaaa',
#  'Lol 0 views',
#  'Sorry for this H79😁andHi🥰😁🙂',
#  'Ohhh thanks',
#  'COOL',
#  '😁😁😁',
#  nan,
#  'yes it do like i love you',
#  'pls teach me how to tie this ur heatie pls',
#  'Early😏😏',
#  'Early!',
#  'Early!!!',
#  'Chile….Anyways….SOOOOOO',
#  'I thought u were a nun at first 😳',
#  'Wow 😯..',
#  'I love ur videos so much .. u make me happy every day ❤️..',
#  'SAME',
#  'earlyy',
#  'EARLY!!!',
#  'Early :)',
#  'Hey',
#  'Early!!!!!!!!',
#  'tf',
#  '@hattiedenny something we’ll never use but good to know about',
#  'Spanish',
#  'Hiii',
#  'The other room',
#  'why are they all guys? (not hating just asking)',
#  'Hi',
#  'Where de chicks ?',
#  'Hey',
#  '😂😂😂😂😂Dead 💀',
#  '🥰💝🇺🇸I can find where though?🇺🇸🇬🇧🇨🇦😄😱🥰',
#  '😳',
#  'I agree ☝️',
#  'Was that guy wearing a Miami university shirt',
#  'No it’s not it’s just an all boy class',
#  'It’s an all boy school',
#  'frr',
#  'FYI chegg is undergoing a massive data breach lawsuit',
#  'So Apple has a scandal called flexgate. They knowingly sold faulty MacBooks. They deleted comments on their support form to cover it up',
#  nan,
#  'Do you have video/procedure for hospital/medical bill forgiveness?',
#  'Also I did a video about it',
#  'to you*',
#  'Thank you girlie:)',
#  'Your kind words mean a lot 💞',
#  'Ideally we will get paid tmw',
#  'Yeah I literally just got paid out $250 for that class action. Filed it 6 years ago….',
#  'We love the sponsorship also this website is absolute flames',
#  'dam I would use this last year but like I loved last year so much I reapted it again',
#  'second 🥰🥰🥰',
#  'Hiiiii',
#  'Hi lovieee',
#  'HI',
#  'Me',
#  'Ayyyy',
#  'What’s UPP',
#  'early',
#  'Do you reply?',
#  'Ayyy I am not early at all',
#  'get that bag 🤪',
#  'Early',
#  '😳🌝',
#  'Earlyyyy',
#  '73th',
#  'ayyyyy',
#  'I’m just trying to educate him like he wanted 🤷🏻\u200d♀️',
#  'Same here but I think this person is American',
#  'Lmao good for you? 😂',
#  'Okay so will I',
#  'You too 😂',
#  'I’m so glad I came across you ma’am @Aviana Dominic my financial debt is now a thing of the past. God bless you ma’am',
#  'Your a very kind person 🥰',
#  'No problem 😁',
#  'Can I get a hi 🥰 your my favourite and first to like!',
#  'OMG',
#  'Does the king reply? 👑',
#  'I’ll do what i want thankssss',
#  'Uni is stresssssfffffuuuuulllllllll',
#  'thanks',
#  'Does the goat reply? Pls do it will make my day 😅',
#  'Ya',
#  nan,
#  'Hi',
#  'Damn',
#  'Hi!',
#  '1st lol',
#  nan,
#  'hii saksham',
#  'i like ur video',
#  'Hi',
#  'thats help a lot',
#  'i try that that is so helping thxx saksham',
#  'ya',
#  'Yo',
#  nan,
#  'Beautiful laptop @sydneyserena 💻',
#  'thank uuuu😍😍',
#  'KONNICHIWA 🥺',
#  '@meilanijoi',
#  'Yesssss I always got my books with them too. So much cheaper than the campus bookstore 😌',
#  "I don't know there was an assignment",
#  '👏🏾 So true!',
#  'Yasss 🔥🔥',
#  nan,
#  '🥰🥰🥰🥰',
#  nan,
#  'Thank you mate 🥰',
#  'Do you have any tips on how to set up your notes?',
#  'this is awesome I have my first exam of the term tomorrow thank you!!',
#  '😌✌️',
#  'Yess',
#  'Sameee!!!',
#  'where was this when i was in school?!',
#  'stop why did i not realise this was an ad i was oh tbt to her study series',
#  'Except that most people just use it to cheat',
#  'YASSSS so useful!!!',
#  nan,
#  'Early',
#  'ay yo thirdddd😁',
#  'First',
#  'First 😏',
#  'Cheg rules 😏😏😏',
#  'Dose he reply????',
#  'oui',
#  '@kissekaten AHHH JAAAA',
#  'Hi! I really need help I have a project due and I want to make it stand out. How do I do that?!?',
#  '@_autmn6 dieses mädchen ist meine motivation die elent manchmal um 3 uhr',
#  'Oui',
#  '$2.50c.',
#  'Norwegian + American = <3',
#  'Omg I mean chegg 😂😂😂😂😂',
#  'Thanj you',
#  'you with everything',
#  'me on thursday 😳😳',
#  '@brenleylol POV it’s you',
#  'Hii',
#  'LMAO',
#  '@kateunderhill_ literally me last night',
#  'Love your videos so much',
#  'omg',
#  'Yess',
#  'Thanks Bestiee',
#  'one of the best ads',
#  'Wait where can I find it for 5$',
#  'I came here to see your braided-bun tutorial for my interview the other day! I am a college writing instructor as well and just realized you were!',
#  'You just gained a new follower😘😘😘😘',
#  'Omg I used to study in Harper all the time.. good mems',
#  "let's go",
#  'My mother in law actually made them to wear some 45 years ago 😂',
#  '😂',
#  '😂',
#  'hahaha the way you dress 😂😂',
#  'my friend has that bag',
#  'Me too!!!! Also please continue to portray her as “college Audri”',
#  '😂',
#  '😂',
#  '😂',
#  'This sentence makes my brain hurt',
#  'First.',
#  'I love your content so much! it makes my day 🥰🥰🥰',
#  'Thank you!!🥰🥰',
#  'heyy Early😁😁😁',
#  'hayyy',
#  'Same',
#  'AYYY',
#  'HI',
#  '46 seconds ago…. I feel like a new person',
#  'Google.',
#  'Ayyyy',
#  'Ikr 😂😂😂',
#  'ayyyy what’s up',
#  'biology is easy it geometry',
#  'Hi i’m your biggest fan',
#  'i want to be in the front of that class',
#  'haaa hee',
#  nan,
#  nan,
#  '@Cheyenne mr wheeler',
#  'Why do I like your voice so much and the way you present literally everything!! Talk about using ur talent!',
#  nan,
#  'Hey I just wanted to say thank you because my check for $36 off the Johnson & Johnson lawsuit just came!',
#  '💥',
#  'Early',
#  'FIRST',
#  'First😬',
#  'HII',
#  'you so nice',
#  '🐄🐄🐄',
#  "I'm sad I am not first 😔",
#  'Where is my early gang',
#  'iam here',
#  'iam firts dude',
#  'Hey',
#  'tysm xx',
#  'Thank you Syd 💞',
#  'Cute',
#  'Chegg has tutors to help in a PhD program? i don’t even know what they’d help me with 😂',
#  '@holly_mc4',
#  'Should’ve had this when I was in school 😌😌',
#  'Puke',
#  ...]

# %%
'''
Checking dictionary created
'''
count = 0
for k, v in comments_dict.iteritems():
    print(k, v)
    count += 1
    if count > 10:
        break
# Out:
# 0 appar
# 1 chegg
# 2 good
# 3 rat
# 4 student
# 5 audri
# 6 differ
# 7 hope
# 8 look
# 9 absolut
# 10 love

# %% [markdown]
# ### Training the model

# %%
lda_model =  gensim.models.LdaMulticore(bow_corpus, 
                                   num_topics = 4, 
                                   id2word = comments_dict,                                    
                                   passes = 10,
                                   workers = 2)
for idx, topic in lda_model.print_topics(-1):
    print("Topic: {} \nWords: {}".format(idx, topic ))
    print("\n")
# Out:
# Topic: 0
# Words: 0.015*"studi" + 0.013*"need" + 0.010*"liter" + 0.010*"time" + 0.009*"help" + 0.009*"chegg" + 0.009*"beauti" + 0.008*"grade" + 0.008*"problem" + 0.008*"guy"
#
#
# Topic: 1
# Words: 0.028*"chegg" + 0.025*"help" + 0.014*"math" + 0.013*"free" + 0.013*"know" + 0.011*"repli" + 0.010*"healthi" + 0.010*"person" + 0.009*"ayyyi" + 0.009*"nice"
#
#
# Topic: 2
# Words: 0.018*"school" + 0.015*"think" + 0.014*"chegg" + 0.012*"like" + 0.010*"say" + 0.010*"teacher" + 0.010*"thank" + 0.009*"colleg" + 0.009*"second" + 0.008*"life"
#
#
# Topic: 3
# Words: 0.066*"love" + 0.039*"video" + 0.033*"earli" + 0.027*"thank" + 0.019*"like" + 0.017*"look" + 0.013*"colleg" + 0.010*"amaz" + 0.009*"week" + 0.008*"class"

# %% [markdown]
# ### Testing the model

# %%
unseen_document = 'I hate Chegg. What a failure!'# Data preprocessing step for the unseen document
bow_vector = comments_dict.doc2bow(preprocess(unseen_document))

for index, score in sorted(lda_model[bow_vector], key=lambda tup: -1*tup[1]):
    print(f"Topic: {index} Score: {score}\t, Topic detail:{lda_model.print_topic(index, 5)}")
# Out:
# Topic: 0 Score: 0.7214055061340332	, Topic detail:0.015*"studi" + 0.013*"need" + 0.010*"liter" + 0.010*"time" + 0.009*"help"
# Topic: 1 Score: 0.10505945235490799	, Topic detail:0.028*"chegg" + 0.025*"help" + 0.014*"math" + 0.013*"free" + 0.013*"know"
# Topic: 2 Score: 0.09018310159444809	, Topic detail:0.018*"school" + 0.015*"think" + 0.014*"chegg" + 0.012*"like" + 0.010*"say"
# Topic: 3 Score: 0.08335191011428833	, Topic detail:0.066*"love" + 0.039*"video" + 0.033*"earli" + 0.027*"thank" + 0.019*"like"

# %% [raw]
# pyLDAvis.enable_notebook()
# pyLDAvis.sklearn.prepare(lda_model, comments_dict,bow_corpus,mds='tsne')

# %% [markdown]
# # TFIDF

# %% [markdown]
# ### Preprocessing

# %%
docs_raw = df.comment.fillna('').tolist()
print(len(docs_raw))
tf_vectorizer = CountVectorizer(strip_accents = 'unicode',
                                stop_words = 'english',
                                lowercase = True,
                                token_pattern = r'\b[a-zA-Z]{3,}\b',
                                max_df = 0.5, 
                                min_df = 10)
dtm_tf = tf_vectorizer.fit_transform(docs_raw)
tfidf_vectorizer = TfidfVectorizer(**tf_vectorizer.get_params())
dtm_tfidf = tfidf_vectorizer.fit_transform(docs_raw)
# Out:
# 1096
# /home/traffic/.local/lib/python3.8/site-packages/sklearn/feature_extraction/text.py:2029: UserWarning: Only (<class 'numpy.float64'>, <class 'numpy.float32'>, <class 'numpy.float16'>) 'dtype' should be used. <class 'numpy.int64'> 'dtype' will be converted to np.float64.
#   warnings.warn(

# %%
dtm_tfidf[0]
# Out:
# <1x41 sparse matrix of type '<class 'numpy.float64'>'
# 	with 0 stored elements in Compressed Sparse Row format>

# %% [markdown]
# ### Training The Model

# %%
# for TF DTM
lda_tf = LatentDirichletAllocation(n_components=6, random_state=0)
lda_tf.fit(dtm_tf)
# for TFIDF DTM
lda_tfidf = LatentDirichletAllocation(n_components=6, random_state=0)
lda_tfidf.fit(dtm_tfidf)
# Out:
# LatentDirichletAllocation(n_components=6, random_state=0)

# %% [markdown]
# ### Visualizing The Result

# %%
pyLDAvis.sklearn.prepare(lda_tf, dtm_tf, tf_vectorizer)
# Out:
# /home/traffic/.local/lib/python3.8/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
# /home/traffic/.local/lib/python3.8/site-packages/pyLDAvis/_prepare.py:246: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   default_term_info = default_term_info.sort_values(
# PreparedData(topic_coordinates=              x         y  topics  cluster       Freq
# topic
# 3     -0.194227  0.323506       1        1  21.733461
# 4      0.221420 -0.038442       2        1  20.569181
# 1     -0.278729 -0.230633       3        1  16.092245
# 5      0.103129  0.128118       4        1  14.833117
# 2      0.186843 -0.058452       5        1  13.428575
# 0     -0.038437 -0.124097       6        1  13.343421, topic_info=      Term       Freq      Total Category  logprob  loglift
# 25    love  66.000000  66.000000  Default  30.0000  30.0000
# 8    early  36.000000  36.000000  Default  29.0000  29.0000
# 32     syd  29.000000  29.000000  Default  28.0000  28.0000
# 1    chegg  36.000000  36.000000  Default  27.0000  27.0000
# 21    like  28.000000  28.000000  Default  26.0000  26.0000
# ..     ...        ...        ...      ...      ...      ...
# 18    just   0.162971  30.801420   Topic6  -6.4619  -3.2276
# 39  videos   0.162725  22.551028   Topic6  -6.4634  -2.9173
# 34   thank   0.162681  21.881394   Topic6  -6.4637  -2.8875
# 25    love   0.162663  66.367335   Topic6  -6.4638  -3.9971
# 38   video   0.162635  23.781564   Topic6  -6.4640  -2.9710
#
# [258 rows x 6 columns], token_table=      Topic      Freq       Term
# term
# 0         5  0.084271    amazing
# 0         6  0.842706    amazing
# 1         1  0.974453      chegg
# 2         1  0.399865      class
# 2         2  0.599797      class
# 3         2  0.370883    college
# 3         4  0.576930    college
# 4         2  0.955117        day
# 5         2  0.946971        did
# 6         6  0.957386       does
# 7         3  0.971179        don
# 8         6  0.969975      early
# 9         4  0.674561        eat
# 9         5  0.337280        eat
# 10        6  0.957386       free
# 11        1  0.905547       good
# 12        1  0.941698        got
# 13        1  0.851351      great
# 13        5  0.085135      great
# 14        2  0.299420      happy
# 14        3  0.149710      happy
# 14        6  0.449130      happy
# 15        2  0.755499    healthy
# 15        5  0.188875    healthy
# 16        5  0.270196       help
# 16        6  0.720522       help
# 17        4  0.910709        hey
# 18        1  0.973981       just
# 19        3  0.931100       know
# 20        3  0.953735       life
# 21        3  0.971791       like
# 22        1  0.215344  literally
# 22        4  0.717812  literally
# 23        3  0.931099        lol
# 24        3  0.966193       look
# 25        2  0.994465       love
# 26        2  0.770646       make
# 26        5  0.140118       make
# 27        4  0.910709       math
# 28        5  0.951637       need
# 29        5  0.947851        omg
# 30        2  0.707703     really
# 30        5  0.272193     really
# 31        1  0.972108     school
# 32        5  0.961254        syd
# 33        4  0.937840     sydney
# 34        4  0.914019      thank
# 34        5  0.091402      thank
# 35        4  0.961972     thanks
# 36        1  0.954566        use
# 37        1  0.392040       used
# 37        2  0.098010       used
# 37        6  0.392040       used
# 38        1  0.967136      video
# 39        2  0.399095     videos
# 39        5  0.532127     videos
# 40        3  0.936589        yes, R=30, lambda_step=0.01, plot_opts={'xlab': 'PC1', 'ylab': 'PC2'}, topic_order=[4, 5, 2, 6, 3, 1])

# %%
unseen_document = 'I hate Chegg. What a failure!'# Data preprocessing step for the unseen document
bow_vector = comments_dict.doc2bow(preprocess(unseen_document))

for index, score in sorted(lda_model[bow_vector], key=lambda tup: -1*tup[1]):
    print(f"Topic: {index} Score: {score}\t, Topic detail:{lda_model.print_topic(index, 5)}")
